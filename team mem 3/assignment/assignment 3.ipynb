# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# ls: cannot open directory '.': Transport endpoint is not connected

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-d02965efecb6> in <module>
# ----> 1 content/drive/MyDrive()
#
# NameError: name 'content' is not defined

# %%
ls
# Out:
#  363139700049630_signed.pdf
#  812919106028_EC8452.pdf
# '812919106028_ec8453 (1).pdf'
#  812919106028_ec8453.pdf
#  812919106028_GE8291.pdf
# '812919106028_MA8451 (1).pdf'
#  812919106028_MA8451.pdf
#  812919106028_PH8151.pdf
# 'Animal_Dataset (1).zip'
# 'ANNEXURE 1 and 2.pdf'
#  Assignment_1-1.ipynb
#  Classroom/
# 'cn record 1.docx'
# 'colab dataset'/
# 'Colab Notebooks'/
# 'CT model exam.docx'
# 'CT model exam.pdf'
# 'data sets'/
#  EC8563-Comm-Networks-Lab-converted.docx
# 'Edited - 812919106028_GE8291.pdf'
# 'Fees pdf'/
#  General_Instructions.pdf
# 'https:  www (1).tnesevai.tn.gov.in'
# 'https:  www.tnesevai.tn.gov.in'
# 'keerthi assignment.pdf'
# 'Land records'/
# 'print out'
# 'project dataset'/
#  Screenshot_2022-02-01-19-17-37-167_com.google.android.youtube.jpg
# 'Skill certificates'/
# 'solider health.pdf'
# 'star topalogy.docx'
#  STUCOR-AU-EXAMS-2021-2.pdf
# 'Thala vivek 2021'/
# 'Thala vivek 9 pro'/
# 'Thozanin Tholgalum.mp3'
# 'UNIT III SCAN COPY.pdf'
# ...

# %%
# !unzip Flowers-Dataset.zip
# Out:
# unzip:  cannot find or open Flowers-Dataset.zip, Flowers-Dataset.zip.zip or Flowers-Dataset.zip.ZIP.
